# %%
import subprocess

# 启动外部程序 C 生成输入数据
def generate_input_from_C():
    result = subprocess.run([r"C:\Users\Daud\Documents\cpp_code\cpp\newpalce\winter\2025-01-11\C\G\release.exe"], check=True, capture_output=True, text=True)
    return result.stdout  # 保留换行符，原始输出

def run_program(program, input_data):
    result = subprocess.run([program], input=input_data, capture_output=True, text=True, check=True, timeout=5)
    return result.stdout

def compare_and_save_outputs(input_data, output_A, output_B):
    if output_A != output_B:
        print(f"Mismatch detected for input:\n{input_data}")
        print(f"A.exe Output: {output_A}")
        print(f"B.exe Output: {output_B}")
        # 保存错误信息到文件
        with open("errors.txt", "a") as f:
            f.write(f"Input: {input_data}\n")
            f.write(f"A.exe Output: {output_A}\n")
            f.write(f"B.exe Output: {output_B}\n\n")
    else:
        print(f"ans = {output_A}")

# 单线程执行程序，捕获和保存错误数据
def single_thread_execution(programs, num_tests=10):
    count = 0
    while count < num_tests:
        # 通过外部程序 C 生成输入数据
        input_data = generate_input_from_C()
        try:
        # 运行 A.exe 和 B.exe，将 C.exe 的输出作为标准输入传递
            output_A = run_program(programs[0], input_data)
            output_B = run_program(programs[1], input_data)
        except:
            print(input_data)
            break
        # 比较并保存输出
        compare_and_save_outputs(input_data, output_A, output_B)

        count += 1
        print(str(count)+" times")

if __name__ == "__main__":
    # 定义要比较的多个程序
    programs = [r"C:\Users\Daud\Documents\cpp_code\cpp\newpalce\winter\2025-01-11\C\1\release.exe", r"C:\Users\Daud\Documents\cpp_code\cpp\newpalce\winter\2025-01-11\C\2\release.exe"]  # 这里只比较 A.exe 和 B.exe，C.exe 仅生成数据

    # 启动单线程执行
    single_thread_execution(programs, num_tests=1000)  # 启动 10 个测试用例
# Out:
# ans = 1 2
#
# 1 times
# ans = 1 2
#
# 2 times
# ans = 1 2
#
# 3 times
# ans = 1 2
#
# 4 times
# ans = 1 2
#
# 5 times
# ans = 1 2
#
# 6 times
# ans = 1 1
#
# 7 times
# ans = 1 2
#
# 8 times
# ans = 1 2
#
# 9 times
# ans = 1 2
#
# 10 times
# ans = 1 2
#
# 11 times
# ans = 1 1
#
# 12 times
# ans = 1 2
#
# 13 times
# ans = 1 4
#
# 14 times
# ans = 1 2
#
# 15 times
# ans = 1 2
#
# 16 times
# ans = 1 2
#
# 17 times
# ans = 1 2
#
# 18 times
# ans = 1 2
#
# 19 times
# ans = 1 2
#
# 20 times
# ans = 1 1
#
# 21 times
# ans = 1 2
#
# 22 times
# ans = 1 2
#
# 23 times
# ans = 1 1
#
# 24 times
# ans = 1 2
#
# 25 times
# ans = 1 2
#
# 26 times
# ans = 1 1
#
# 27 times
# ans = 1 2
#
# 28 times
# ans = 1 2
#
# 29 times
# ans = 1 2
#
# 30 times
# ans = 1 1
#
# 31 times
# ans = 1 2
#
# 32 times
# ans = 1 2
#
# 33 times
# ans = 1 2
#
# 34 times
# ans = 1 2
#
# 35 times
# ans = 1 2
#
# 36 times
# ans = 1 1
#
# 37 times
# ans = 1 1
#
# 38 times
# ans = 1 1
#
# 39 times
# ans = 1 1
#
# 40 times
# ans = 1 1
#
# 41 times
# ans = 1 1
#
# 42 times
# ans = 1 1
#
# 43 times
# ans = 1 1
#
# 44 times
# ans = 1 1
#
# 45 times
# ans = 1 1
#
# 46 times
# ans = 1 1
#
# 47 times
# ans = 1 1
#
# 48 times
# ans = 1 1
#
# 49 times
# ans = 1 1
#
# 50 times
# ans = 1 1
#
# 51 times
# ans = 1 1
#
# 52 times
# ans = 1 1
#
# 53 times
# ans = 1 2
#
# 54 times
# ans = 1 2
#
# 55 times
# ans = 1 2
#
# 56 times
# ans = 1 2
#
# 57 times
# ans = 1 2
#
# 58 times
# ans = 1 3
#
# 59 times
# ans = 1 2
#
# 60 times
# ans = 1 2
#
# 61 times
# ans = 1 2
#
# 62 times
# ans = 1 2
#
# 63 times
# ans = 1 2
#
# 64 times
# ans = 1 2
#
# 65 times
# ans = 1 2
#
# 66 times
# ans = 1 2
#
# 67 times
# ans = 1 2
#
# 68 times
# ans = 1 2
#
# 69 times
# ans = 1 2
#
# 70 times
# ans = 1 1
#
# 71 times
# ans = 1 1
#
# 72 times
# ans = 1 1
#
# 73 times
# ans = 1 1
#
# 74 times
# ans = 1 1
#
# 75 times
# ans = 1 1
#
# 76 times
# ans = 1 1
#
# 77 times
# ans = 1 1
#
# 78 times
# ans = 1 1
#
# 79 times
# ans = 1 1
#
# 80 times
# ans = 1 1
#
# 81 times
# ans = 1 1
#
# 82 times
# ans = 1 1
#
# 83 times
# ans = 1 1
#
# 84 times
# ans = 1 1
#
# 85 times
# ans = 1 1
#
# 86 times
# ans = 1 1
#
# 87 times
# ans = 1 1
#
# 88 times
# ans = 3 1
#
# 89 times
# ans = 3 1
#
# 90 times
# ans = 3 1
#
# 91 times
# ans = 3 1
#
# 92 times
# ans = 1 1
#
# 93 times
# ans = 3 1
#
# 94 times
# ans = 3 1
#
# 95 times
# ans = 1 1
#
# 96 times
# ans = 3 1
#
# 97 times
# ans = 3 1
#
# 98 times
# ans = 3 1
#
# 99 times
# ans = 3 1
#
# 100 times
# ans = 1 1
#
# 101 times
# ans = 3 1
#
# 102 times
# ans = 3 1
#
# 103 times
# ans = 3 1
#
# 104 times
# ans = 3 1
#
# 105 times
# ans = 1 1
#
# 106 times
# ans = 1 1
#
# 107 times
# ans = 1 1
#
# 108 times
# ans = 1 1
#
# 109 times
# ans = 1 3
#
# 110 times
# ans = 1 1
#
# 111 times
# ans = 1 1
#
# 112 times
# ans = 1 1
#
# 113 times
# ans = 1 1
#
# 114 times
# ans = 1 1
#
# 115 times
# ans = 1 1
#
# 116 times
# ans = 1 2
#
# 117 times
# ans = 1 1
#
# 118 times
# ans = 1 2
#
# 119 times
# ans = 1 1
#
# 120 times
# ans = 1 1
#
# 121 times
# ans = 1 1
#
# 122 times
# ans = 1 2
#
# 123 times
# ans = 1 2
#
# 124 times
# ans = 1 1
#
# 125 times
# ans = 1 2
#
# 126 times
# ans = 1 2
#
# 127 times
# ans = 1 2
#
# 128 times
# ans = 1 2
#
# 129 times
# ans = 1 2
#
# 130 times
# ans = 1 2
#
# 131 times
# ans = 1 2
#
# 132 times
# ans = 1 1
#
# 133 times
# ans = 1 2
#
# 134 times
# ans = 2 2
#
# 135 times
# ans = 1 2
#
# 136 times
# ans = 1 2
#
# 137 times
# ans = 2 2
#
# 138 times
# ans = 2 2
#
# 139 times
# ans = 1 3
#
# 140 times
# ans = 1 1
#
# 141 times
# ans = 1 1
#
# 142 times
# ans = 1 1
#
# 143 times
# ans = 1 1
#
# 144 times
# ans = 1 1
#
# 145 times
# ans = 1 1
#
# 146 times
# ans = 1 1
#
# 147 times
# ans = 1 1
#
# 148 times
# ans = 1 1
#
# 149 times
# ans = 1 1
#
# 150 times
# ans = 1 1
#
# 151 times
# ans = 1 1
#
# 152 times
# ans = 1 1
#
# 153 times
# ans = 1 1
#
# 154 times
# ans = 1 1
#
# 155 times
# ans = 1 1
#
# 156 times
# ans = 1 1
#
# 157 times
# ans = 1 1
#
# 158 times
# ans = 1 1
#
# 159 times
# ans = 1 1
#
# 160 times
# ans = 1 1
#
# 161 times
# ans = 1 1
#
# 162 times
# ans = 2 2
#
# 163 times
# ans = 1 1
#
# 164 times
# ans = 1 1
#
# 165 times
# ans = 1 1
#
# 166 times
# ans = 1 1
#
# 167 times
# ans = 1 1
#
# 168 times
# ans = 1 1
#
# 169 times
# ans = 1 1
#
# 170 times
# ans = 1 1
#
# 171 times
# ans = 1 1
#
# 172 times
# ans = 1 1
#
# 173 times
# ans = 1 1
#
# 174 times
# ans = 1 1
#
# 175 times
# ans = 1 1
#
# 176 times
# ans = 1 1
#
# 177 times
# ans = 1 1
#
# 178 times
# ans = 1 1
#
# 179 times
# ans = 1 1
#
# 180 times
# ans = 1 1
#
# 181 times
# ans = 1 1
#
# 182 times
# ans = 1 1
#
# 183 times
# ans = 1 1
#
# 184 times
# ans = 1 1
#
# 185 times
# ans = 1 1
#
# 186 times
# ans = 1 1
#
# 187 times
# ans = 1 1
#
# 188 times
# ans = 1 1
#
# 189 times
# ans = 1 1
#
# 190 times
# ans = 1 1
#
# 191 times
# ans = 1 1
#
# 192 times
# ans = 1 2
#
# 193 times
# ans = 1 2
#
# 194 times
# ans = 1 2
#
# 195 times
# ans = 1 2
#
# 196 times
# ans = 1 2
#
# 197 times
# ans = 1 2
#
# 198 times
# ans = 1 2
#
# 199 times
# ans = 1 2
#
# 200 times
# ans = 1 2
#
# 201 times
# ans = 1 2
#
# 202 times
# ans = 1 2
#
# 203 times
# ans = 1 2
#
# 204 times
# ans = 1 2
#
# 205 times
# ans = 1 2
#
# 206 times
# ans = 1 2
#
# 207 times
# ans = 1 2
#
# 208 times
# ans = 1 2
#
# 209 times
# ans = 1 2
#
# 210 times
# ans = 1 2
#
# 211 times
# ans = 1 1
#
# 212 times
# ans = 1 1
#
# 213 times
# ans = 1 1
#
# 214 times
# ans = 1 1
#
# 215 times
# ans = 1 1
#
# 216 times
# ans = 1 1
#
# 217 times
# ans = 1 1
#
# 218 times
# ans = 1 1
#
# 219 times
# ans = 1 1
#
# 220 times
# ans = 1 1
#
# 221 times
# ans = 1 1
#
# 222 times
# ans = 1 1
#
# 223 times
# ans = 1 1
#
# 224 times
# ans = 1 1
#
# 225 times
# ans = 1 1
#
# 226 times
# ans = 1 1
#
# 227 times
# ans = 1 2
#
# 228 times
# ans = 1 1
#
# 229 times
# ans = 1 2
#
# 230 times
# ans = 1 3
#
# 231 times
# ans = 1 2
#
# 232 times
# ans = 1 2
#
# 233 times
# ans = 1 1
#
# 234 times
# ans = 1 2
#
# 235 times
# ans = 1 2
#
# 236 times
# ans = 1 2
#
# 237 times
# ans = 1 2
#
# 238 times
# ans = 1 2
#
# 239 times
# ans = 1 2
#
# 240 times
# ans = 1 2
#
# 241 times
# ans = 1 2
#
# 242 times
# ans = 1 2
#
# 243 times
# ans = 1 2
#
# 244 times
# ans = 1 1
#
# 245 times
# ans = 1 1
#
# 246 times
# ans = 1 1
#
# 247 times
# ans = 1 1
#
# 248 times
# ans = 1 1
#
# 249 times
# ans = 1 1
#
# 250 times
# ans = 1 1
#
# 251 times
# ans = 1 1
#
# 252 times
# ans = 1 1
#
# 253 times
# ans = 1 1
#
# 254 times
# ans = 1 1
#
# 255 times
# ans = 1 1
#
# 256 times
# ans = 1 1
#
# 257 times
# ans = 1 1
#
# 258 times
# ans = 1 1
#
# 259 times
# ans = 1 1
#
# 260 times
# ans = 1 2
#
# 261 times
# ans = 1 1
#
# 262 times
# ans = 1 1
#
# 263 times
# ans = 1 3
#
# 264 times
# ans = 1 1
#
# 265 times
# ans = 1 1
#
# 266 times
# ans = 1 1
#
# 267 times
# ans = 1 1
#
# 268 times
# ans = 1 1
#
# 269 times
# ans = 1 1
#
# 270 times
# ans = 1 3
#
# 271 times
# ans = 1 3
#
# 272 times
# ans = 1 1
#
# 273 times
# ans = 1 1
#
# 274 times
# ans = 1 1
#
# 275 times
# ans = 1 1
#
# 276 times
# ans = 1 1
#
# 277 times
# ans = 1 1
#
# 278 times
# ans = 1 1
#
# 279 times
# ans = 1 1
#
# 280 times
# ans = 1 1
#
# 281 times
# ans = 1 1
#
# 282 times
# ans = 1 1
#
# 283 times
# ans = 1 1
#
# 284 times
# ans = 1 1
#
# 285 times
# ans = 1 1
#
# 286 times
# ans = 1 1
#
# 287 times
# ans = 1 1
#
# 288 times
# ans = 1 1
#
# 289 times
# ans = 1 1
#
# 290 times
# ans = 1 1
#
# 291 times
# ans = 1 1
#
# 292 times
# ans = 1 1
#
# 293 times
# ans = 1 1
#
# 294 times
# ans = 1 1
#
# 295 times
# ans = 1 1
#
# 296 times
# ans = 1 1
#
# 297 times
# ans = 1 2
#
# 298 times
# ans = 1 2
#
# 299 times
# ans = 1 2
#
# 300 times
# ans = 1 2
#
# 301 times
# ans = 1 2
#
# 302 times
# ans = 1 1
#
# 303 times
# ans = 1 2
#
# 304 times
# ans = 1 2
#
# 305 times
# ans = 1 2
#
# 306 times
# ans = 1 2
#
# 307 times
# ans = 1 2
#
# 308 times
# ans = 1 2
#
# 309 times
# ans = 1 1
#
# 310 times
# ans = 1 3
#
# 311 times
# ans = 1 2
#
# 312 times
# ans = 1 2
#
# 313 times
# ans = 1 1
#
# 314 times
# ans = 1 1
#
# 315 times
# ans = 1 1
#
# 316 times
# ans = 1 1
#
# 317 times
# ans = 1 1
#
# 318 times
# ans = 1 1
#
# 319 times
# ans = 1 1
#
# 320 times
# ans = 1 1
#
# 321 times
# ans = 1 1
#
# 322 times
# ans = 1 1
#
# 323 times
# ans = 1 1
#
# 324 times
# ans = 1 1
#
# 325 times
# ans = 1 1
#
# 326 times
# ans = 1 1
#
# 327 times
# ans = 1 1
#
# 328 times
# ans = 1 1
#
# 329 times
# ans = 1 1
#
# 330 times
# ans = 1 1
#
# 331 times
# ans = 1 1
#
# 332 times
# ans = 1 1
#
# 333 times
# ans = 1 2
#
# 334 times
# ans = 1 1
#
# 335 times
# ans = 1 1
#
# 336 times
# ans = 1 2
#
# 337 times
# ans = 1 1
#
# 338 times
# ans = 1 1
#
# 339 times
# ans = 1 1
#
# 340 times
# ans = 1 1
#
# 341 times
# ans = 1 2
#
# 342 times
# ans = 1 1
#
# 343 times
# ans = 1 1
#
# 344 times
# ans = 1 1
#
# 345 times
# ans = 1 1
#
# 346 times
# ans = 1 1
#
# 347 times
# ans = 1 1
#
# 348 times
# ans = 1 1
#
# 349 times
# ans = 1 1
#
# 350 times
# ans = 1 1
#
# 351 times
# ans = 1 1
#
# 352 times
# ans = 1 1
#
# 353 times
# ans = 1 1
#
# 354 times
# ans = 1 1
#
# 355 times
# ans = 1 1
#
# 356 times
# ans = 1 1
#
# 357 times
# ans = 1 1
#
# 358 times
# ans = 1 1
#
# 359 times
# ans = 1 1
#
# 360 times
# ans = 1 1
#
# 361 times
# ans = 1 1
#
# 362 times
# ans = 1 1
#
# 363 times
# ans = 1 1
#
# 364 times
# ans = 1 1
#
# 365 times
# ans = 1 1
#
# 366 times
# ans = 1 1
#
# 367 times
# ans = 1 3
#
# 368 times
# ans = 1 1
#
# 369 times
# ans = 1 1
#
# 370 times
# ans = 1 1
#
# 371 times
# ans = 1 1
#
# 372 times
# ans = 1 1
#
# 373 times
# ans = 1 1
#
# 374 times
# ans = 1 1
#
# 375 times
# ans = 1 1
#
# 376 times
# ans = 1 1
#
# 377 times
# ans = 1 1
#
# 378 times
# ans = 1 4
#
# 379 times
# ans = 1 4
#
# 380 times
# ans = 1 4
#
# 381 times
# ans = 1 1
#
# 382 times
# ans = 1 4
#
# 383 times
# ans = 1 4
#
# 384 times
# ans = 1 4
#
# 385 times
# ans = 1 1
#
# 386 times
# ans = 1 1
#
# 387 times
# ans = 1 4
#
# 388 times
# ans = 1 4
#
# 389 times
# ans = 1 1
#
# 390 times
# ans = 1 1
#
# 391 times
# ans = 1 4
#
# 392 times
# ans = 1 2
#
# 393 times
# ans = 1 4
#
# 394 times
# ans = 1 2
#
# 395 times
# ans = 1 2
#
# 396 times
# ans = 3 1
#
# 397 times
# ans = 1 2
#
# 398 times
# ans = 1 2
#
# 399 times
# ans = 1 2
#
# 400 times
# ans = 1 1
#
# 401 times
# ans = 1 4
#
# 402 times
# ans = 1 2
#
# 403 times
# ans = 1 2
#
# 404 times
# ans = 1 1
#
# 405 times
# ans = 1 2
#
# 406 times
# ans = 1 1
#
# 407 times
# ans = 1 2
#
# 408 times
# ans = 1 2
#
# 409 times
# ans = 1 2
#
# 410 times
# ans = 1 2
#
# 411 times
# ans = 1 1
#
# 412 times
# ans = 1 2
#
# 413 times
# ans = 1 1
#
# 414 times
# ans = 1 1
#
# 415 times
# ans = 1 2
#
# 416 times
# ans = 1 2
#
# 417 times
# ans = 1 1
#
# 418 times
# ans = 1 2
#
# 419 times
# ans = 1 1
#
# 420 times
# ans = 1 2
#
# 421 times
# ans = 1 2
#
# 422 times
# ans = 1 2
#
# 423 times
# ans = 1 1
#
# 424 times
# ans = 1 2
#
# 425 times
# ans = 1 2
#
# 426 times
# ans = 1 2
#
# 427 times
# ans = 1 1
#
# 428 times
# ans = 1 1
#
# 429 times
# ans = 1 1
#
# 430 times
# ans = 1 1
#
# 431 times
# ans = 1 1
#
# 432 times
# ans = 1 1
#
# 433 times
# ans = 1 1
#
# 434 times
# ans = 1 1
#
# 435 times
# ans = 1 1
#
# 436 times
# ans = 1 1
#
# 437 times
# ans = 1 1
#
# 438 times
# ans = 1 1
#
# 439 times
# ans = 1 1
#
# 440 times
# ans = 1 1
#
# 441 times
# ans = 1 1
#
# 442 times
# ans = 1 1
#
# 443 times
# ans = 1 1
#
# 444 times
# ans = 1 1
#
# 445 times
# ans = 1 1
#
# 446 times
# ans = 2 1
#
# 447 times
# ans = 1 2
#
# 448 times
# ans = 2 1
#
# 449 times
# ans = 1 1
#
# 450 times
# ans = 2 1
#
# 451 times
# ans = 2 1
#
# 452 times
# ans = 2 1
#
# 453 times
# ans = 1 2
#
# 454 times
# ans = 2 1
#
# 455 times
# ans = 1 2
#
# 456 times
# ans = 2 1
#
# 457 times
# ans = 2 1
#
# 458 times
# ans = 2 1
#
# 459 times
# ans = 2 1
#
# 460 times
# ans = 2 1
#
# 461 times
# ans = 2 1
#
# 462 times
# ans = 1 2
#
# 463 times
# ans = 2 1
#
# 464 times
# ans = 1 2
#
# 465 times
# ans = 1 2
#
# 466 times
# ans = 1 2
#
# 467 times
# ans = 1 2
#
# 468 times
# ans = 1 2
#
# 469 times
# ans = 1 2
#
# 470 times
# ans = 1 1
#
# 471 times
# ans = 1 1
#
# 472 times
# ans = 1 2
#
# 473 times
# ans = 1 2
#
# 474 times
# ans = 1 2
#
# 475 times
# ans = 1 1
#
# 476 times
# ans = 1 2
#
# 477 times
# ans = 1 2
#
# 478 times
# ans = 1 2
#
# 479 times
# ans = 1 2
#
# 480 times
# ans = 1 1
#
# 481 times
# ans = 1 1
#
# 482 times
# ans = 1 2
#
# 483 times
# ans = 1 2
#
# 484 times
# ans = 1 2
#
# 485 times
# ans = 1 1
#
# 486 times
# ans = 1 2
#
# 487 times
# ans = 1 1
#
# 488 times
# ans = 1 1
#
# 489 times
# ans = 1 1
#
# 490 times
# ans = 1 1
#
# 491 times
# ans = 1 2
#
# 492 times
# ans = 1 1
#
# 493 times
# ans = 1 2
#
# 494 times
# ans = 1 1
#
# 495 times
# ans = 1 2
#
# 496 times
# ans = 1 1
#
# 497 times
# ans = 1 1
#
# 498 times
# ans = 1 1
#
# 499 times
# ans = 1 1
#
# 500 times
# ans = 2 1
#
# 501 times
# ans = 1 1
#
# 502 times
# ans = 1 1
#
# 503 times
# ans = 1 1
#
# 504 times
# ans = 1 1
#
# 505 times
# ans = 2 1
#
# 506 times
# ans = 1 1
#
# 507 times
# ans = 1 1
#
# 508 times
# ans = 1 1
#
# 509 times
# ans = 1 1
#
# 510 times
# ans = 1 1
#
# 511 times
# ans = 2 1
#
# 512 times
# ans = 1 1
#
# 513 times
# ans = 1 1
#
# 514 times
# ans = 2 1
#
# 515 times
# ans = 1 1
#
# 516 times
# ans = 2 1
#
# 517 times
# ans = 2 1
#
# 518 times
# ans = 1 1
#
# 519 times
# ans = 1 3
#
# 520 times
# ans = 1 2
#
# 521 times
# ans = 1 2
#
# 522 times
# ans = 1 2
#
# 523 times
# ans = 1 2
#
# 524 times
# ans = 1 2
#
# 525 times
# ans = 1 2
#
# 526 times
# ans = 1 1
#
# 527 times
# ans = 1 3
#
# 528 times
# ans = 1 2
#
# 529 times
# ans = 1 2
#
# 530 times
# ans = 1 2
#
# 531 times
# ans = 1 2
#
# 532 times
# ans = 1 3
#
# 533 times
# ans = 1 2
#
# 534 times
# ans = 1 3
#
# 535 times
# ans = 1 2
#
# 536 times
# ans = 1 2
#
# 537 times
# ans = 1 1
#
# 538 times
# ans = 1 1
#
# 539 times
# ans = 1 1
#
# 540 times
# ans = 1 1
#
# 541 times
# ans = 1 1
#
# 542 times
# ans = 1 1
#
# 543 times
# ans = 1 1
#
# 544 times
# ans = 3 1
#
# 545 times
# ans = 1 1
#
# 546 times
# ans = 1 1
#
# 547 times
# ans = 1 1
#
# 548 times
# ans = 1 1
#
# 549 times
# ans = 1 1
#
# 550 times
# ans = 1 1
#
# 551 times
# ans = 1 1
#
# 552 times
# ans = 1 1
#
# 553 times
# ans = 1 1
#
# 554 times
# ans = 1 1
#
# 555 times
# ans = 1 1
#
# 556 times
# ans = 1 1
#
# 557 times
# ans = 1 3
#
# 558 times
# ans = 1 1
#
# 559 times
# ans = 1 1
#
# 560 times
# ans = 1 1
#
# 561 times
# ans = 1 1
#
# 562 times
# ans = 1 1
#
# 563 times
# ans = 1 1
#
# 564 times
# ans = 1 1
#
# 565 times
# ans = 1 3
#
# 566 times
# ans = 1 1
#
# 567 times
# ans = 1 1
#
# 568 times
# ans = 1 3
#
# 569 times
# ans = 1 1
#
# 570 times
# ans = 1 1
#
# 571 times
# ans = 1 1
#
# 572 times
# ans = 1 2
#
# 573 times
# ans = 2 1
#
# 574 times
# ans = 1 1
#
# 575 times
# ans = 2 1
#
# 576 times
# ans = 1 1
#
# 577 times
# ans = 2 1
#
# 578 times
# ans = 2 1
#
# 579 times
# ans = 2 1
#
# 580 times
# ans = 2 1
#
# 581 times
# ans = 2 1
#
# 582 times
# ans = 2 1
#
# 583 times
# ans = 2 1
#
# 584 times
# ans = 2 1
#
# 585 times
# ans = 2 1
#
# 586 times
# ans = 2 1
#
# 587 times
# ans = 1 1
#
# 588 times
# ans = 1 1
#
# 589 times
# ans = 1 2
#
# 590 times
# ans = 1 2
#
# 591 times
# ans = 1 2
#
# 592 times
# ans = 1 1
#
# 593 times
# ans = 1 2
#
# 594 times
# ans = 1 2
#
# 595 times
# ans = 1 2
#
# 596 times
# ans = 1 2
#
# 597 times
# ans = 1 2
#
# 598 times
# ans = 1 2
#
# 599 times
# ans = 1 2
#
# 600 times
# ans = 1 1
#
# 601 times
# ans = 1 2
#
# 602 times
# ans = 5 1
#
# 603 times
# ans = 1 2
#
# 604 times
# ans = 1 1
#
# 605 times
# ans = 1 2
#
# 606 times
# ans = 1 2
#
# 607 times
# ans = 2 1
#
# 608 times
# ans = 1 1
#
# 609 times
# ans = 1 1
#
# 610 times
# ans = 2 1
#
# 611 times
# ans = 1 1
#
# 612 times
# ans = 1 1
#
# 613 times
# ans = 1 1
#
# 614 times
# ans = 1 1
#
# 615 times
# ans = 1 1
#
# 616 times
# ans = 1 1
#
# 617 times
# ans = 2 1
#
# 618 times
# ans = 1 1
#
# 619 times
# ans = 2 1
#
# 620 times
# ans = 2 1
#
# 621 times
# ans = 2 1
#
# 622 times
# ans = 1 1
#
# 623 times
# ans = 1 1
#
# 624 times
# ans = 1 1
#
# 625 times
# ans = 1 2
#
# 626 times
# ans = 1 2
#
# 627 times
# ans = 1 2
#
# 628 times
# ans = 1 2
#
# 629 times
# ans = 1 2
#
# 630 times
# ans = 1 2
#
# 631 times
# ans = 1 2
#
# 632 times
# ans = 1 2
#
# 633 times
# ans = 1 1
#
# 634 times
# ans = 1 2
#
# 635 times
# ans = 1 2
#
# 636 times
# ans = 6 1
#
# 637 times
# ans = 1 2
#
# 638 times
# ans = 1 2
#
# 639 times
# ans = 1 1
#
# 640 times
# ans = 6 1
#
# 641 times
# ans = 1 2
#
# 642 times
# ans = 1 2
#
# 643 times
# ans = 1 1
#
# 644 times
# ans = 1 1
#
# 645 times
# ans = 1 2
#
# 646 times
# ans = 1 1
#
# 647 times
# ans = 1 1
#
# 648 times
# ans = 1 1
#
# 649 times
# ans = 1 1
#
# 650 times
# ans = 1 1
#
# 651 times
# ans = 1 1
#
# 652 times
# ans = 1 1
#
# 653 times
# ans = 1 1
#
# 654 times
# ans = 1 1
#
# 655 times
# ans = 1 2
#
# 656 times
# ans = 1 1
#
# 657 times
# ans = 1 1
#
# 658 times
# ans = 1 1
#
# 659 times
# ans = 1 1
#
# 660 times
# ans = 1 1
#
# 661 times
# ans = 1 1
#
# 662 times
# ans = 1 1
#
# 663 times
# ans = 1 1
#
# 664 times
# ans = 1 1
#
# 665 times
# ans = 1 1
#
# 666 times
# ans = 1 1
#
# 667 times
# ans = 1 1
#
# 668 times
# ans = 1 2
#
# 669 times
# ans = 1 1
#
# 670 times
# ans = 1 1
#
# 671 times
# ans = 1 1
#
# 672 times
# ans = 1 1
#
# 673 times
# ans = 1 1
#
# 674 times
# ans = 1 3
#
# 675 times
# ans = 1 1
#
# 676 times
# ans = 1 1
#
# 677 times
# ans = 1 3
#
# 678 times
# ans = 1 2
#
# 679 times
# ans = 1 1
#
# 680 times
# ans = 1 1
#
# 681 times
# ans = 1 1
#
# 682 times
# ans = 1 1
#
# 683 times
# ans = 1 1
#
# 684 times
# ans = 1 1
#
# 685 times
# ans = 1 2
#
# 686 times
# ans = 1 1
#
# 687 times
# ans = 1 2
#
# 688 times
# ans = 1 2
#
# 689 times
# ans = 1 2
#
# 690 times
# ans = 1 1
#
# 691 times
# ans = 1 1
#
# 692 times
# ans = 1 2
#
# 693 times
# ans = 1 2
#
# 694 times
# ans = 1 2
#
# 695 times
# ans = 1 2
#
# 696 times
# ans = 1 1
#
# 697 times
# ans = 1 1
#
# 698 times
# ans = 1 1
#
# 699 times
# ans = 1 2
#
# 700 times
# ans = 1 1
#
# 701 times
# ans = 3 1
#
# 702 times
# ans = 3 1
#
# 703 times
# ans = 3 1
#
# 704 times
# ans = 3 1
#
# 705 times
# ans = 1 2
#
# 706 times
# ans = 3 1
#
# 707 times
# ans = 3 1
#
# 708 times
# ans = 3 1
#
# 709 times
# ans = 1 1
#
# 710 times
# ans = 3 1
#
# 711 times
# ans = 3 1
#
# 712 times
# ans = 1 1
#
# 713 times
# ans = 3 1
#
# 714 times
# ans = 3 1
#
# 715 times
# ans = 1 1
#
# 716 times
# ans = 1 1
#
# 717 times
# ans = 1 1
#
# 718 times
# ans = 1 1
#
# 719 times
# ans = 1 1
#
# 720 times
# ans = 1 1
#
# 721 times
# ans = 1 1
#
# 722 times
# ans = 1 1
#
# 723 times
# ans = 1 1
#
# 724 times
# ans = 1 1
#
# 725 times
# ans = 1 1
#
# 726 times
# ans = 1 1
#
# 727 times
# ans = 1 1
#
# 728 times
# ans = 1 1
#
# 729 times
# ans = 1 1
#
# 730 times
# ans = 1 1
#
# 731 times
# ans = 1 1
#
# 732 times
# ans = 1 2
#
# 733 times
# ans = 1 1
#
# 734 times
# ans = 1 1
#
# 735 times
# ans = 1 1
#
# 736 times
# ans = 3 1
#
# 737 times
# ans = 1 1
#
# 738 times
# ans = 1 1
#
# 739 times
# ans = 1 1
#
# 740 times
# ans = 1 2
#
# 741 times
# ans = 1 1
#
# 742 times
# ans = 1 1
#
# 743 times
# ans = 1 1
#
# 744 times
# ans = 1 1
#
# 745 times
# ans = 1 1
#
# 746 times
# ans = 1 1
#
# 747 times
# ans = 1 1
#
# 748 times
# ans = 1 1
#
# 749 times
# ans = 1 4
#
# 750 times
# ans = 1 1
#
# 751 times
# ans = 1 1
#
# 752 times
# ans = 1 1
#
# 753 times
# ans = 1 1
#
# 754 times
# ans = 1 1
#
# 755 times
# ans = 1 1
#
# 756 times
# ans = 1 1
#
# 757 times
# ans = 1 1
#
# 758 times
# ans = 1 1
#
# 759 times
# ans = 1 1
#
# 760 times
# ans = 1 1
#
# 761 times
# ans = 1 1
#
# 762 times
# ans = 1 1
#
# 763 times
# ans = 1 1
#
# 764 times
# ans = 1 1
#
# 765 times
# ans = 1 2
#
# 766 times
# ans = 1 2
#
# 767 times
# ans = 1 2
#
# 768 times
# ans = 1 2
#
# 769 times
# ans = 1 2
#
# 770 times
# ans = 1 2
#
# 771 times
# ans = 1 2
#
# 772 times
# ans = 1 1
#
# 773 times
# ans = 1 2
#
# 774 times
# ans = 1 2
#
# 775 times
# ans = 1 2
#
# 776 times
# ans = 1 4
#
# 777 times
# ans = 1 2
#
# 778 times
# ans = 1 2
#
# 779 times
# ans = 1 1
#
# 780 times
# ans = 1 2
#
# 781 times
# ans = 1 2
#
# 782 times
# ans = 1 2
#
# 783 times
# ans = 1 1
#
# 784 times
# ans = 1 1
#
# 785 times
# ans = 1 1
#
# 786 times
# ans = 1 1
#
# 787 times
# ans = 1 1
#
# 788 times
# ans = 1 1
#
# 789 times
# ans = 1 1
#
# 790 times
# ans = 1 1
#
# 791 times
# ans = 1 1
#
# 792 times
# ans = 1 1
#
# 793 times
# ans = 1 1
#
# 794 times
# ans = 1 1
#
# 795 times
# ans = 1 1
#
# 796 times
# ans = 1 1
#
# 797 times
# ans = 1 1
#
# 798 times
# ans = 1 1
#
# 799 times
# ans = 1 1
#
# 800 times
# ans = 2 1
#
# 801 times
# ans = 1 3
#
# 802 times
# ans = 2 1
#
# 803 times
# ans = 2 1
#
# 804 times
# ans = 2 1
#
# 805 times
# ans = 2 1
#
# 806 times
# ans = 2 1
#
# 807 times
# ans = 2 1
#
# 808 times
# ans = 2 1
#
# 809 times
# ans = 2 1
#
# 810 times
# ans = 1 2
#
# 811 times
# ans = 2 1
#
# 812 times
# ans = 2 1
#
# 813 times
# ans = 2 1
#
# 814 times
# ans = 2 1
#
# 815 times
# ans = 1 1
#
# 816 times
# ans = 1 1
#
# 817 times
# ans = 1 1
#
# 818 times
# ans = 1 1
#
# 819 times
# ans = 1 1
#
# 820 times
# ans = 1 1
#
# 821 times
# ans = 1 1
#
# 822 times
# ans = 1 1
#
# 823 times
# ans = 1 1
#
# 824 times
# ans = 1 1
#
# 825 times
# ans = 1 1
#
# 826 times
# ans = 1 1
#
# 827 times
# ans = 1 1
#
# 828 times
# ans = 1 1
#
# 829 times
# ans = 1 1
#
# 830 times
# ans = 1 1
#
# 831 times
# ans = 1 1
#
# 832 times
# ans = 1 1
#
# 833 times
# ans = 1 1
#
# 834 times
# ans = 1 1
#
# 835 times
# ans = 1 2
#
# 836 times
# ans = 1 1
#
# 837 times
# ans = 1 1
#
# 838 times
# ans = 1 1
#
# 839 times
# ans = 1 1
#
# 840 times
# ans = 1 2
#
# 841 times
# ans = 1 3
#
# 842 times
# ans = 2 1
#
# 843 times
# ans = 1 1
#
# 844 times
# ans = 1 1
#
# 845 times
# ans = 1 1
#
# 846 times
# ans = 1 1
#
# 847 times
# ans = 1 1
#
# 848 times
# ans = 1 1
#
# 849 times
# ans = 1 1
#
# 850 times
# ans = 1 1
#
# 851 times
# ans = 1 1
#
# 852 times
# ans = 1 1
#
# 853 times
# ans = 1 1
#
# 854 times
# ans = 1 1
#
# 855 times
# ans = 1 1
#
# 856 times
# ans = 1 1
#
# 857 times
# ans = 1 1
#
# 858 times
# ans = 1 1
#
# 859 times
# ans = 1 1
#
# 860 times
# ans = 1 3
#
# 861 times
# ans = 1 1
#
# 862 times
# ans = 1 2
#
# 863 times
# ans = 1 1
#
# 864 times
# ans = 1 1
#
# 865 times
# ans = 1 1
#
# 866 times
# ans = 1 1
#
# 867 times
# ans = 1 3
#
# 868 times
# ans = 1 3
#
# 869 times
# ans = 1 3
#
# 870 times
# ans = 1 3
#
# 871 times
# ans = 1 2
#
# 872 times
# ans = 1 3
#
# 873 times
# ans = 1 3
#
# 874 times
# ans = 1 3
#
# 875 times
# ans = 1 3
#
# 876 times
# ans = 1 3
#
# 877 times
# ans = 1 1
#
# 878 times
# ans = 1 3
#
# 879 times
# ans = 1 3
#
# 880 times
# ans = 1 3
#
# 881 times
# ans = 1 2
#
# 882 times
# ans = 1 3
#
# 883 times
# ans = 1 3
#
# 884 times
# ans = 1 1
#
# 885 times
# ans = 1 1
#
# 886 times
# ans = 1 2
#
# 887 times
# ans = 1 1
#
# 888 times
# ans = 1 1
#
# 889 times
# ans = 1 1
#
# 890 times
# ans = 1 1
#
# 891 times
# ans = 1 1
#
# 892 times
# ans = 1 1
#
# 893 times
# ans = 1 1
#
# 894 times
# ans = 1 2
#
# 895 times
# ans = 1 1
#
# 896 times
# ans = 1 1
#
# 897 times
# ans = 1 2
#
# 898 times
# ans = 1 1
#
# 899 times
# ans = 1 1
#
# 900 times
# ans = 1 1
#
# 901 times
# ans = 1 2
#
# 902 times
# ans = 1 2
#
# 903 times
# ans = 1 2
#
# 904 times
# ans = 1 1
#
# 905 times
# ans = 1 2
#
# 906 times
# ans = 1 3
#
# 907 times
# ans = 1 2
#
# 908 times
# ans = 1 2
#
# 909 times
# ans = 1 2
#
# 910 times
# ans = 1 2
#
# 911 times
# ans = 1 3
#
# 912 times
# ans = 1 2
#
# 913 times
# ans = 1 1
#
# 914 times
# ans = 1 2
#
# 915 times
# ans = 1 2
#
# 916 times
# ans = 1 3
#
# 917 times
# ans = 1 2
#
# 918 times
# ans = 1 1
#
# 919 times
# ans = 1 1
#
# 920 times
# ans = 1 1
#
# 921 times
# ans = 1 1
#
# 922 times
# ans = 1 1
#
# 923 times
# ans = 1 1
#
# 924 times
# ans = 1 1
#
# 925 times
# ans = 1 1
#
# 926 times
# ans = 1 1
#
# 927 times
# ans = 1 1
#
# 928 times
# ans = 1 1
#
# 929 times
# ans = 1 1
#
# 930 times
# ans = 1 1
#
# 931 times
# ans = 1 1
#
# 932 times
# ans = 1 1
#
# 933 times
# ans = 1 1
#
# 934 times
# ans = 1 1
#
# 935 times
# ans = 1 1
#
# 936 times
# ans = 1 1
#
# 937 times
# ans = 1 1
#
# 938 times
# ans = 1 1
#
# 939 times
# ans = 1 1
#
# 940 times
# ans = 1 2
#
# 941 times
# ans = 1 1
#
# 942 times
# ans = 1 1
#
# 943 times
# ans = 1 1
#
# 944 times
# ans = 1 1
#
# 945 times
# ans = 1 1
#
# 946 times
# ans = 1 1
#
# 947 times
# ans = 1 1
#
# 948 times
# ans = 1 1
#
# 949 times
# ans = 1 1
#
# 950 times
# ans = 1 1
#
# 951 times
# ans = 1 1
#
# 952 times
# ans = 1 2
#
# 953 times
# ans = 1 1
#
# 954 times
# ans = 1 1
#
# 955 times
# ans = 1 1
#
# 956 times
# ans = 1 1
#
# 957 times
# ans = 1 1
#
# 958 times
# ans = 1 1
#
# 959 times
# ans = 1 1
#
# 960 times
# ans = 1 1
#
# 961 times
# ans = 1 1
#
# 962 times
# ans = 1 1
#
# 963 times
# ans = 1 1
#
# 964 times
# ans = 1 1
#
# 965 times
# ans = 1 1
#
# 966 times
# ans = 1 1
#
# 967 times
# ans = 1 1
#
# 968 times
# ans = 1 1
#
# 969 times
# ans = 1 1
#
# 970 times
# ans = 1 1
#
# 971 times
# ans = 1 3
#
# 972 times
# ans = 1 3
#
# 973 times
# ans = 1 3
#
# 974 times
# ans = 1 1
#
# 975 times
# ans = 1 3
#
# 976 times
# ans = 1 3
#
# 977 times
# ans = 1 2
#
# 978 times
# ans = 1 2
#
# 979 times
# ans = 1 3
#
# 980 times
# ans = 1 3
#
# 981 times
# ans = 1 3
#
# 982 times
# ans = 1 3
#
# 983 times
# ans = 1 1
#
# 984 times
# ans = 1 1
#
# 985 times
# ans = 1 4
#
# 986 times
# ans = 1 1
#
# 987 times
# ans = 1 1
#
# 988 times
# ans = 1 4
#
# 989 times
# ans = 1 1
#
# 990 times
# ans = 1 4
#
# 991 times
# ans = 1 1
#
# 992 times
# ans = 1 1
#
# 993 times
# ans = 1 4
#
# 994 times
# ans = 1 1
#
# 995 times
# ans = 1 4
#
# 996 times
# ans = 1 1
#
# 997 times
# ans = 1 1
#
# 998 times
# ans = 1 4
#
# 999 times
# ans = 1 4
#
# 1000 times
